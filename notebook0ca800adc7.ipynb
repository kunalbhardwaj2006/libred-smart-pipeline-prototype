# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/kbkunalbhardwaj/libred-prototype-zip/libred-smart-pipeline-prototype-main/libred-smart-pipeline-prototype-main/metrics.py
# /kaggle/input/datasets/kbkunalbhardwaj/libred-prototype-zip/libred-smart-pipeline-prototype-main/libred-smart-pipeline-prototype-main/.gitignore
# /kaggle/input/datasets/kbkunalbhardwaj/libred-prototype-zip/libred-smart-pipeline-prototype-main/libred-smart-pipeline-prototype-main/main.py
# /kaggle/input/datasets/kbkunalbhardwaj/libred-prototype-zip/libred-smart-pipeline-prototype-main/libred-smart-pipeline-prototype-main/README.md
# /kaggle/input/datasets/kbkunalbhardwaj/libred-prototype-zip/libred-smart-pipeline-prototype-main/libred-smart-pipeline-prototype-main/async_pipeline.py
# /kaggle/input/datasets/kbkunalbhardwaj/libred-prototype-zip/libred-smart-pipeline-prototype-main/libred-smart-pipeline-prototype-main/app.py
# ...

# %%
# !ls -R /kaggle/input
# Out:
# /kaggle/input:
# datasets
#
# /kaggle/input/datasets:
# kbkunalbhardwaj
#
# /kaggle/input/datasets/kbkunalbhardwaj:
# libred-prototype-zip
#
# /kaggle/input/datasets/kbkunalbhardwaj/libred-prototype-zip:
# libred-smart-pipeline-prototype-main
#
# /kaggle/input/datasets/kbkunalbhardwaj/libred-prototype-zip/libred-smart-pipeline-prototype-main:
# libred-smart-pipeline-prototype-main
#
# /kaggle/input/datasets/kbkunalbhardwaj/libred-prototype-zip/libred-smart-pipeline-prototype-main/libred-smart-pipeline-prototype-main:
# app.py		   cache.py  metrics.py  README.md
# async_pipeline.py  main.py   outputs	 sample_data
#
# /kaggle/input/datasets/kbkunalbhardwaj/libred-prototype-zip/libred-smart-pipeline-prototype-main/libred-smart-pipeline-prototype-main/outputs:
# cache.json  metrics.json  results.json
#
# /kaggle/input/datasets/kbkunalbhardwaj/libred-prototype-zip/libred-smart-pipeline-prototype-main/libred-smart-pipeline-prototype-main/sample_data:
# questions.json

# %%
import shutil

src = "/kaggle/input/datasets/kbkunalbhardwaj/libred-prototype-zip/libred-smart-pipeline-prototype-main/libred-smart-pipeline-prototype-main"
dst = "/kaggle/working/project"

shutil.copytree(src, dst, dirs_exist_ok=True)

print("✅ Project copied successfully")
# Out:
# ✅ Project copied successfully

# %%
# %cd /kaggle/working/project
# !ls
# Out:
# /kaggle/working/project
# app.py		   cache.py  metrics.py  README.md
# async_pipeline.py  main.py   outputs	 sample_data

# %%
# !rm -rf outputs/cache.json
print("🧹 Cache cleared")
# Out:
# 🧹 Cache cleared

# %%
import time

start = time.time()
# !python3 main.py
print(f"⏱️ First Run Time: {time.time() - start:.2f}s")
# Out:
# 🚀 Starting Smart Async Pipeline...
#
#
# 📥 Total Input Questions: 3
# 🧠 Unique Questions After Dedup: 2
#
# ❌ Cache MISS for q1
# ❌ Cache MISS for q2
# ⚡ Batch processed in 0.50s
#
# ✅ Results saved to outputs/results.json
#
# 📊 FINAL METRICS REPORT
# ...
# Total Requests: 2
# Cache Hits: 0
# Cache Miss: 2
# Cache Hit Rate: 0.00%
# Total Processing Time: 1.00s
# ...
# ⏱️ First Run Time: 0.77s

# %%
import time

start = time.time()
# !python3 main.py
print(f"⏱️ Second Run Time: {time.time() - start:.2f}s")
# Out:
# 🚀 Starting Smart Async Pipeline...
#
#
# 📥 Total Input Questions: 3
# 🧠 Unique Questions After Dedup: 2
#
# ⚡ Cache HIT for q1
# ⚡ Cache HIT for q2
# ⚡ Batch processed in 0.00s
#
# ✅ Results saved to outputs/results.json
#
# 📊 FINAL METRICS REPORT
# ...
# Total Requests: 2
# Cache Hits: 2
# Cache Miss: 0
# Cache Hit Rate: 100.00%
# Total Processing Time: 0.00s
# ...
# ⏱️ Second Run Time: 0.26s

# %%
# !cat outputs/metrics.json
# Out:
# {
#   "total_requests": 2,
#   "cache_hits": 2,
#   "cache_miss": 0,
#   "total_time": 0,
#   "cache_hit_rate": 100.0
# }

# %%
# !zip -r outputs.zip outputs
# Out:
#   adding: outputs/ (stored 0%)
#   adding: outputs/cache.json (deflated 63%)
#   adding: outputs/results.json (deflated 63%)
#   adding: outputs/metrics.json (deflated 39%)
